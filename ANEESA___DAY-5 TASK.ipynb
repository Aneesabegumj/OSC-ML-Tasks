# %% [markdown]
# # DAY - 5 TASK

# %%
# importing the necessary libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.simplefilter("ignore")

# %%
# Importing the Car_purchasing Dataset

df=pd.read_csv("car_purchasing.csv",encoding='ISO-8859-1')
df
# Out:
#           country  gender        age  average_annual_Salary  \
# 0        Bulgaria       0  41.851720            62812.09301
# 1          Belize       0  40.870623            66646.89292
# 2         Algeria       1  43.152897            53798.55112
# 3    Cook Islands       1  58.271369            79370.03798
# 4          Brazil       1  57.313749            59729.15130
# ..            ...     ...        ...                    ...
# 495         Nepal       0  41.462515            71942.40291
# 496      Zimbabwe       1  37.642000            56039.49793
# 497   Philippines       1  53.943497            68888.77805
# 498      Botswana       1  59.160509            49811.99062
# 499        marlal       1  46.731152            61370.67766
#
#      average_credit_card_debt    net_worth  car_purchase_amount
# 0                11609.380910  238961.2505          35321.45877
# 1                 9572.957136  530973.9078          45115.52566
# ...

# %%
# Checking the head of the dataframe

df.head()
# Out:
#         country  gender        age  average_annual_Salary  \
# 0      Bulgaria       0  41.851720            62812.09301
# 1        Belize       0  40.870623            66646.89292
# 2       Algeria       1  43.152897            53798.55112
# 3  Cook Islands       1  58.271369            79370.03798
# 4        Brazil       1  57.313749            59729.15130
#
#    average_credit_card_debt    net_worth  car_purchase_amount
# 0              11609.380910  238961.2505          35321.45877
# 1               9572.957136  530973.9078          45115.52566
# 2              11160.355060  638467.1773          42925.70921
# 3              14426.164850  548599.0524          67422.36313
# 4               5358.712177  560304.0671          55915.46248

# %%
# Checking the shape of the dataframe

df.shape
# Out:
# (500, 7)

# %%
# Checking the info of the dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   500 non-null    object
#  1   gender                    500 non-null    int64
#  2   age                       500 non-null    float64
#  3   average_annual_Salary     500 non-null    float64
#  4   average_credit_card_debt  500 non-null    float64
#  5   net_worth                 500 non-null    float64
#  6   car_purchase_amount       500 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 27.5+ KB

# %%
# Checking the null values of the dataframe

df.isnull().sum()
# Out:
# country                     0
# gender                      0
# age                         0
# average_annual_Salary       0
# average_credit_card_debt    0
# net_worth                   0
# car_purchase_amount         0
# dtype: int64

# %%
# Removing the unnecessary column(country) of the dataframe

new_df=df.drop(['country'],axis=1)
new_df
# Out:
#      gender        age  average_annual_Salary  average_credit_card_debt  \
# 0         0  41.851720            62812.09301              11609.380910
# 1         0  40.870623            66646.89292               9572.957136
# 2         1  43.152897            53798.55112              11160.355060
# 3         1  58.271369            79370.03798              14426.164850
# 4         1  57.313749            59729.15130               5358.712177
# ..      ...        ...                    ...                       ...
# 495       0  41.462515            71942.40291               6995.902524
# 496       1  37.642000            56039.49793              12301.456790
# 497       1  53.943497            68888.77805              10611.606860
# 498       1  59.160509            49811.99062              14013.034510
# 499       1  46.731152            61370.67766               9391.341628
#
#        net_worth  car_purchase_amount
# 0    238961.2505          35321.45877
# ...

# %%
# Describing the Statistics of the dataframe

new_df.describe()
# Out:
#            gender         age  average_annual_Salary  \
# count  500.000000  500.000000             500.000000
# mean     0.506000   46.241674           62127.239608
# std      0.500465    7.978862           11703.378228
# min      0.000000   20.000000           20000.000000
# 25%      0.000000   40.949969           54391.977195
# 50%      1.000000   46.049901           62915.497035
# 75%      1.000000   51.612263           70117.862005
# max      1.000000   70.000000          100000.000000
#
#        average_credit_card_debt       net_worth  car_purchase_amount
# count                500.000000      500.000000           500.000000
# mean                9607.645049   431475.713625         44209.799218
# std                 3489.187973   173536.756340         10773.178744
# min                  100.000000    20000.000000          9000.000000
# 25%                 7397.515792   299824.195900         37629.896040
# 50%                 9655.035568   426750.120650         43997.783390
# ...

# %%
# Checking the number of males and females

new_df['gender'].value_counts()
# Out:
# 1    253
# 0    247
# Name: gender, dtype: int64

# %%
# Visualizing using Boxplot for gender

sns.boxplot(new_df['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
# Visualizing using Boxplot for average_annual_salary

sns.boxplot(new_df['average_annual_Salary'])
# Out:
# <AxesSubplot:xlabel='average_annual_Salary'>

# %%
# Visualizing using distplot for car_purchase_amount

sns.distplot(new_df['car_purchase_amount'])
# Out:
# <AxesSubplot:xlabel='car_purchase_amount', ylabel='Density'>

# %%
# Visualizing using pairplot

sns.pairplot(new_df)

# %%
# Splitting the dataset into Independent(X) and Dependent(y) Variables

x=new_df.iloc[:,:5]
y=new_df.iloc[:,5]

# %%
# Displaying Independent variable

x
# Out:
#      gender        age  average_annual_Salary  average_credit_card_debt  \
# 0         0  41.851720            62812.09301              11609.380910
# 1         0  40.870623            66646.89292               9572.957136
# 2         1  43.152897            53798.55112              11160.355060
# 3         1  58.271369            79370.03798              14426.164850
# 4         1  57.313749            59729.15130               5358.712177
# ..      ...        ...                    ...                       ...
# 495       0  41.462515            71942.40291               6995.902524
# 496       1  37.642000            56039.49793              12301.456790
# 497       1  53.943497            68888.77805              10611.606860
# 498       1  59.160509            49811.99062              14013.034510
# 499       1  46.731152            61370.67766               9391.341628
#
#        net_worth
# 0    238961.2505
# 1    530973.9078
# 2    638467.1773
# 3    548599.0524
# ...

# %%
# Displaying dependent variable

y
# Out:
# 0      35321.45877
# 1      45115.52566
# 2      42925.70921
# 3      67422.36313
# 4      55915.46248
#           ...
# 495    48901.44342
# 496    31491.41457
# 497    64147.28888
# 498    45442.15353
# 499    45107.22566
# Name: car_purchase_amount, Length: 500, dtype: float64

# %%
# Splitting the dataset for training set and testing set

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
#  Fitting Linear regression model to the training set

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Predicting the test results y_pred

y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([22090.56337001, 23519.24695086, 37843.66378455, 43680.18125137,
#        53112.16754176, 47443.11695886, 51868.11612513, 44649.41333962,
#        46133.79370466, 38951.70053244, 59621.58655411, 36110.39371622,
#        34518.66573284, 48103.35242483, 40020.12548951, 46379.60494074,
#        55420.06208628, 70879.44583786, 44419.05273507, 38505.24352341,
#        44734.98208294, 39889.2604347 , 35716.64015536, 60117.33946775,
#        52952.61920915, 63081.60446834, 39810.37845066, 59095.06247517,
#        57430.57135863, 43264.68011781, 30721.00802699, 56067.01929039,
#        58234.95269694, 42703.54819218, 46400.67886132, 52665.68243259,
#        59483.91024246, 55912.96503656, 43241.81984841, 46084.37609491,
#        36545.8254914 , 32061.01680383, 27588.62951832, 44577.22138032,
#        31087.23645104, 31528.19923631, 28439.93285389, 30734.51114839,
#        44361.29452378, 33637.62331259, 42481.17982239, 37742.16607915,
# ...

# %%
# Checking the accuracy score of the model

from sklearn.metrics import r2_score
rsq = r2_score(y_test,y_pred)*100
rsq
# Out:
# 99.99999752373189

# %% [markdown]
# Therefore,our model gives 99.9% accuracy
